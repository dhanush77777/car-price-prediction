# %%
import pandas as pd

# %%
df=pd.read_csv('/content/car data.csv')

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  ...  Seller_Type  Transmission Owner
# 0     ritz  2014           3.35  ...       Dealer        Manual     0
# 1      sx4  2013           4.75  ...       Dealer        Manual     0
# 2     ciaz  2017           7.25  ...       Dealer        Manual     0
# 3  wagon r  2011           2.85  ...       Dealer        Manual     0
# 4    swift  2014           4.60  ...       Dealer        Manual     0
#
# [5 rows x 9 columns]

# %%
df.drop(columns=['Car_Name'],inplace=True)

# %%
df.head()
# Out:
#    Year  Selling_Price  Present_Price  ...  Seller_Type Transmission Owner
# 0  2014           3.35           5.59  ...       Dealer       Manual     0
# 1  2013           4.75           9.54  ...       Dealer       Manual     0
# 2  2017           7.25           9.85  ...       Dealer       Manual     0
# 3  2011           2.85           4.15  ...       Dealer       Manual     0
# 4  2014           4.60           6.87  ...       Dealer       Manual     0
#
# [5 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
print(df['Fuel_Type'].unique())
print(df['Seller_Type'].unique())
print(df['Transmission'].unique())
# Out:
# ['Petrol' 'Diesel' 'CNG']
# ['Dealer' 'Individual']
# ['Manual' 'Automatic']

# %%
df['Current Year']=2021

# %%
df['no of years']=df['Current Year']- df['Year']

# %%
df.head()
# Out:
#    Year  Selling_Price  Present_Price  ...  Owner Current Year no of years
# 0  2014           3.35           5.59  ...      0         2021           7
# 1  2013           4.75           9.54  ...      0         2021           8
# 2  2017           7.25           9.85  ...      0         2021           4
# 3  2011           2.85           4.15  ...      0         2021          10
# 4  2014           4.60           6.87  ...      0         2021           7
#
# [5 rows x 10 columns]

# %%
df=pd.get_dummies(df,drop_first=True)
df.head()
# Out:
#    Year  Selling_Price  ...  Seller_Type_Individual  Transmission_Manual
# 0  2014           3.35  ...                       0                    1
# 1  2013           4.75  ...                       0                    1
# 2  2017           7.25  ...                       0                    1
# 3  2011           2.85  ...                       0                    1
# 4  2014           4.60  ...                       0                    1
#
# [5 rows x 11 columns]

# %%
df.drop(columns=['Current Year'],inplace=True)

# %%
df.head()
# Out:
#    Year  Selling_Price  ...  Seller_Type_Individual  Transmission_Manual
# 0  2014           3.35  ...                       0                    1
# 1  2013           4.75  ...                       0                    1
# 2  2017           7.25  ...                       0                    1
# 3  2011           2.85  ...                       0                    1
# 4  2014           4.60  ...                       0                    1
#
# [5 rows x 10 columns]

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr())

# %%
df.describe()
# Out:
#               Year  Selling_Price  ...  Seller_Type_Individual  Transmission_Manual
# count   301.000000     301.000000  ...              301.000000           301.000000
# mean   2013.627907       4.661296  ...                0.352159             0.867110
# std       2.891554       5.082812  ...                0.478439             0.340021
# min    2003.000000       0.100000  ...                0.000000             0.000000
# 25%    2012.000000       0.900000  ...                0.000000             1.000000
# 50%    2014.000000       3.600000  ...                0.000000             1.000000
# 75%    2016.000000       6.000000  ...                1.000000             1.000000
# max    2018.000000      35.000000  ...                1.000000             1.000000
#
# [8 rows x 10 columns]

# %%
sns.pairplot(df)

# %%
plt.figure(figsize=(20,9))
df.boxplot()

# %%
sns.countplot(df['Owner'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(df['Transmission_Manual'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.scatter(data=df,x='Selling_Price',y='no of years')
plt.xlabel("selling price")
plt.ylabel("no of years")
# Out:
# Text(0, 0.5, 'no of years')

# %%
df1=pd.read_csv('/content/car data.csv')

# %%
df1.head()
# Out:
#   Car_Name  Year  Selling_Price  ...  Seller_Type  Transmission Owner
# 0     ritz  2014           3.35  ...       Dealer        Manual     0
# 1      sx4  2013           4.75  ...       Dealer        Manual     0
# 2     ciaz  2017           7.25  ...       Dealer        Manual     0
# 3  wagon r  2011           2.85  ...       Dealer        Manual     0
# 4    swift  2014           4.60  ...       Dealer        Manual     0
#
# [5 rows x 9 columns]

# %%
df1['Car_Name'].value_counts()
# Out:
# city                  26
# corolla altis         16
# verna                 14
# fortuner              11
# brio                  10
#                       ..
# Hero Glamour           1
# Honda Dream Yuga       1
# Hero  Ignitor Disc     1
# baleno                 1
# corolla                1
# Name: Car_Name, Length: 98, dtype: int64

# %%
train_qs = pd.Series(df1['Car_Name'].tolist()).astype(str)

# %%
from wordcloud import WordCloud
cloud = WordCloud(width=1440, height=1080).generate(" ".join(train_qs.astype(str)))
plt.figure(figsize=(20, 10))
plt.imshow(cloud)
plt.axis('off')
# Out:
# (-0.5, 1439.5, 1079.5, -0.5)

# %%
x=df.iloc[:,[1,3,4,5,6,7,8,9]]
y=df.iloc[:,[2]]

# %%
x.shape,y.shape
# Out:
# ((301, 8), (301, 1))

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()
rf.fit(x,y)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
print(rf.feature_importances_)
# Out:
# [0.84773661 0.04280316 0.00296019 0.08120788 0.00197285 0.00272429
#  0.00791707 0.01267795]

# %%
f = pd.Series(rf.feature_importances_, index=x.columns)
plt.title('top 5 imp features')
f.nlargest(5).plot(kind='barh')
plt.show()
plt.title('all features')
f.plot(kind='barh')
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)

# %%
y_pred=rf.predict(x)
from sklearn.metrics import r2_score,mean_squared_error
import numpy as np

# %%
np.sqrt(mean_squared_error(y,y_pred))
# Out:
# 1.6359837508668356

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
random_grid = {'n_estimators': [100,200,300,400],
               'max_depth': [5,10,15,20],
               'min_samples_split': [2,5,10,15],
               'min_samples_leaf': [1,2,5,10]}

# %%
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,scoring='neg_mean_squared_error', n_iter = 10, cv = 5, verbose=2, random_state=42, n_jobs = 1)

# %%
rf_random.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=5, max_depth=20
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=5, max_depth=20, total=   0.2s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=5, max_depth=20
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# ...

# %%
rf_random.best_params_
# Out:
# {'max_depth': 5,
#  'min_samples_leaf': 1,
#  'min_samples_split': 5,
#  'n_estimators': 300}

# %%
rf_random.best_score_
# Out:
# -25.710241507228506

# %%
plt.scatter(y_pred,y)

# %%
import pickle
# open a file, where you ant to store the data
file = open('random_forest3.pkl', 'wb')

# dump information to that file
pickle.dump(rf_random, file)
